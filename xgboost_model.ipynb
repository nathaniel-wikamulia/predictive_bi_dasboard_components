# %% [markdown]
# #Import Library

# %%
import pandas as pd
import csv
from matplotlib import pyplot as plt
import numpy
import datetime
import seaborn as sns
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import isnan
from google.colab import files
from google.colab import drive

# %% [markdown]
# #Initialize CSV Location and Mount Google Drive

# %%
#Initialize The CSV Directory
dataset_directory = "drive/MyDrive/Dataset Bakery XYZ/"

#Initialize The CSV File Names
directory_area = dataset_directory + "AREA.csv"
directory_customer = dataset_directory + "CUST.csv"
directory_inventory = dataset_directory + "INVENTORY.csv"
directory_sales_header = dataset_directory + "SALESHEADER.csv"
directory_sales_detail = dataset_directory + "SALESDETAIL.csv"

# %%
#Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Data Preprocessing

# %% [markdown]
# ##Perform JOIN on All Tables

# %%
#Data Preprocessing The "Area" Table
area = pd.read_csv(directory_area, ";")

area.drop(['UPDDATE', 'UPDTIME'], inplace=True, axis=1)

desc = area['DESC'].unique()
desc_dict = dict(zip(desc, range(len(desc))))
area = area.applymap(lambda s: desc_dict.get(s) if s in desc_dict else s)

# %%
#Data Preprocessing The "Customer" Table
customer = pd.read_csv(directory_customer, ";",converters={'CODE':str, 'AREACD':str, 'SALTYPE':str, 'CUSTNAME':str, 'ARBAL':str, 'INACTIVE':str})

customer.drop(['UPDDATE', 'UPDTIME'], inplace=True, axis=1)

salestypes = customer['SALTYPE'].unique()
salestypes_dict = dict(zip(salestypes, range(len(salestypes))))
customer = customer.applymap(lambda s: salestypes_dict.get(s) if s in salestypes_dict else s)

(unique, counts) = numpy.unique(customer['INACTIVE'], return_counts=True)
frequencies = numpy.asarray((unique, counts)).T
customer.drop(customer.loc[customer['INACTIVE']==2].index, inplace=True)

inactive = customer['INACTIVE'].unique()
inactive_dict = dict(zip(inactive, range(len(inactive))))
customer = customer.applymap(lambda s: inactive_dict.get(s) if s in inactive_dict else s)

# %%
#Data Preprocessing The "Inventory" Table
inventory = pd.read_csv(directory_inventory, ";")

inventory.drop(['UPDDATE', 'UPDTIME'], inplace=True, axis=1)

inventory['SPRICE'] = inventory['SPRICE'].str.replace(',00', '')
inventory['SPRICE'] = pd.to_numeric(inventory['SPRICE'],errors = 'coerce')

inventory['UCOST'] = inventory['UCOST'].str.replace(',00', '')
inventory['UCOST'] = pd.to_numeric(inventory['UCOST'],errors = 'coerce')

inventory['WEIGHT'] = inventory['WEIGHT'].str.replace(',00', '')
inventory['WEIGHT'] = pd.to_numeric(inventory['WEIGHT'],errors = 'coerce')

# %%
#Data Preprocessing The "Sales Detail" Table
salesDetail = pd.read_csv(directory_sales_detail, ";", quoting=csv.QUOTE_NONE, error_bad_lines=False, converters={'UPRICE':str, 'UCOST':str, 'AMOUNT':str, 'DISCAMT':str})

salesDetail.drop(['UPDDATE', 'UPDTIME'], inplace=True, axis=1)

salesDetail['UPRICE'] = salesDetail['UPRICE'].str.replace(',00', '')
salesDetail['UPRICE'] = pd.to_numeric(salesDetail['UPRICE'],errors = 'coerce')

salesDetail['UCOST'] = salesDetail['UCOST'].str.replace(',00', '')
salesDetail['UCOST'] = pd.to_numeric(salesDetail['UCOST'],errors = 'coerce')

salesDetail['AMOUNT'] = salesDetail['AMOUNT'].str.replace(',00', '')
salesDetail['AMOUNT'] = pd.to_numeric(salesDetail['AMOUNT'],errors = 'coerce')

salesDetail['DISCAMT'] = salesDetail['DISCAMT'].str.replace(',00', '')
salesDetail['DISCAMT'] = pd.to_numeric(salesDetail['DISCAMT'],errors = 'coerce')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Data Preprocessing The "Sales Header" Table
salesHeader = pd.read_csv(directory_sales_header, ";", quoting=csv.QUOTE_NONE, error_bad_lines=False, converters={'TOTAL':str})

salesHeader.drop(['UPDDATE', 'UPDTIME'], inplace=True, axis=1)

salesHeader['TOTAL'] = salesHeader['TOTAL'].str.replace(',00', '')
salesHeader['TOTAL'] = pd.to_numeric(salesHeader['TOTAL'],errors = 'coerce')

STYPE = salesHeader['STYPE'].unique()
STYPE_dict = dict(zip(STYPE, range(len(STYPE))))
salesHeader = salesHeader.applymap(lambda s: STYPE_dict.get(s) if s in STYPE_dict else s)

# %%
#JOIN The "Customer" Table and "Area" Table 
area.rename(columns={"CODE": "AreaID"}, inplace=True)
customer.rename(columns={"AREACD": "AreaID", "CODE": "CustomerID"}, inplace=True)

(unique, counts) = numpy.unique(customer['AreaID'], return_counts=True)
frequencies = numpy.asarray((unique, counts)).T

testJoin = customer.merge(area,
                    on=['AreaID'],
                    how="outer"
                    )

# %%
#JOIN The "Sales Header" Table with The "Customer and Area" Table
salesHeader.rename(columns={"CUSTCODE": "CustomerID"}, inplace=True)

(unique, counts) = numpy.unique(salesHeader['CustomerID'], return_counts=True)
frequencies = numpy.asarray((unique, counts)).T

testJoin.rename(columns={"CODE": "CustomerID"}, inplace=True)

testMultiJoin = testJoin.merge(salesHeader,
                               on=['CustomerID'],
                               how="right"
                               )

# %%
#JOIN The "Sales Detail" Table with The "Sales Header, Customer, and Area" Table
salesDetail.rename(columns={"TRNO": "SalesHeaderID"}, inplace=True)
testMultiJoin.rename(columns={"TRNO": "SalesHeaderID"}, inplace=True)

saleHeaderSalesDetailJoin = testMultiJoin.merge(salesDetail,
                                                on=['SalesHeaderID'],
                                                how="right"
                                                )

# %%
#JOIN The "Inventory" Table with The "Sales Detail, Sales Header, Customer, and Area" Table
saleHeaderSalesDetailJoin.rename(columns={"ITEMNO": "ProductID"}, inplace=True)
inventory.rename(columns={"ITEMNO": "ProductID"}, inplace=True)

MergedData= saleHeaderSalesDetailJoin.merge(inventory,
                                      on=['ProductID'],
                                      how="left"
                               )

# %% [markdown]
# ##Dropping Unused Columns

# %%
#Creating The "YEAR", "MONTH", and "DAY" (Day of The Month) Columns from "TRDATE"
MergedData["TRDATE"] = pd.to_datetime(MergedData["TRDATE"])

MergedData['YEAR'] = MergedData['TRDATE'].dt.year 
MergedData['MONTH'] = MergedData['TRDATE'].dt.month
MergedData['DAY'] = MergedData['TRDATE'].dt.day

# %%
#Creating The "SALDCODE" Column That Acts as The Primary Key
MergedData["LINENO"] = MergedData["LINENO"].astype(str)
MergedData['SALDCODE'] = MergedData['SalesHeaderID'] + MergedData['LINENO']

# %%
#Dropping The Unused Columns
MergedData.drop(['AreaID', 'ProductID', 'CUSTNAME', 'ITEMNAME','TRDATE', 'SALTYPE', 'ARBAL', 'INACTIVE', 'DESC', 'SALPERSON', 'STYPE', 'UCOST_x', 'DISCAMT', 'AMOUNT', 'SPRICE', 'UCOST_y', 'WEIGHT', 'UPRICE', 'SalesHeaderID', 'LINENO'], inplace=True, axis=1)

#Dropping The Empty Rows
cleanMergedData = MergedData.dropna()

# %% [markdown]
# ##Splitting The Transaction Data Per Customer

# %%
#Creating a list of unique CustomerIDs

#unique4: A list containing the CustomerID. This list is unique (no duplicate CustomerID).
#counts4: A list containing the number of occurrences of a CustomerID.
#frequencies4: A 2-dimensional list containing the CustomerID and the number of occurrences of that CustomerID.

(unique4, counts4) = numpy.unique(cleanMergedData['CustomerID'], return_counts=True)
frequencies4 = numpy.asarray((unique4, counts4)).T

# %%
#Creating an "allCustomer" variable that contains all unique CustomerIDs
allCustomer = ["" for x in range(len(unique4))]

for i in range(0, len(unique4)):
  allCustomer[i] = unique4[i]

# %%
#Creating a "dataBasedOnAllCustomer" dictionary whose key is CustomerID and the value is the transaction data from the customer who have the CustomerID
#Creating a "saldCodeBasedOnAllCustomer" dictionary containing the SALDCODE of each CustomerID to simplify the Extract, Transform, and Load (ETL) process to the Data Warehouse

dataBasedOnAllCustomer = {}
saldCodeBasedOnAllCustomer = {}

for customerID in allCustomer:
  segmentedData = cleanMergedData.query('CustomerID == @customerID')
  segmentedData.drop(['CustomerID'], inplace=True, axis=1)
  dataBasedOnAllCustomer[customerID] = segmentedData
  saldCodeBasedOnAllCustomer[customerID] = segmentedData
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#Dropping The Unused Columns
for i in dataBasedOnAllCustomer:
  dataBasedOnAllCustomer[i] = dataBasedOnAllCustomer[i].drop(['SALDCODE'], axis=1)
  saldCodeBasedOnAllCustomer[i] = saldCodeBasedOnAllCustomer[i].drop(['TOTAL', 'QTY', 'QTYRET', 'YEAR', 'MONTH', 'DAY'], axis=1)

# %% [markdown]
# #Data Splitting

# %%
#Creating a New Variable to Accommodate the Preprocessed Data
dataBasedOnAllCustomerClean = {}
saldCodeBasedOnAllCustomerClean = {}

for i in dataBasedOnAllCustomer:
  dataBasedOnAllCustomerClean[i] = dataBasedOnAllCustomer[i]
  saldCodeBasedOnAllCustomerClean[i] = saldCodeBasedOnAllCustomer[i]

# %%
#Splitting The Dataset into Training Features and The Predicted Data
X = {}
y = {}

for i in dataBasedOnAllCustomerClean:
  X[i], y[i] = dataBasedOnAllCustomerClean[i].loc[:, dataBasedOnAllCustomerClean[i].columns != 'QTYRET'], dataBasedOnAllCustomerClean[i].loc[:, dataBasedOnAllCustomerClean[i].columns == 'QTYRET']

# %% [markdown]
# #XGBoost Model Development

# %%
#Creating XGBoost Models with Parameters from The Hyperparameter Tuning Result
regressor = XGBRegressor(learning_rate=0.6, max_depth=5, reg_lambda=0.9, reg_alpha=0.1, subsample=1)

# %%
#Fitting The XGBoost Models with Training Dataset
model = {}

for i in dataBasedOnAllCustomerClean:
  model[i] = regressor.fit(X[i], y[i])

pred_res = {}
predictions = {}

for i in dataBasedOnAllCustomerClean:
  pred_res[i] = model[i].predict(X[i])
  dataBasedOnAllCustomerClean[i]["PREDICTRET"] = [round(value) for value in pred_res[i]]
  dataBasedOnAllCustomerClean[i]["PREDICTQTY"] = dataBasedOnAllCustomerClean[i]["QTY"] - dataBasedOnAllCustomerClean[i]["PREDICTRET"]
# Out:
# [02:12:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:12:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# [02:13:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %% [markdown]
# #Model Evaluation

# %% [markdown]
# ##Root Mean Square Error (RMSE)

# %%
#Calculating The RMSE Score for All Models
rmse = {}

for i in dataBasedOnAllCustomerClean:
  rmse[i] = mean_squared_error(y[i], dataBasedOnAllCustomerClean[i]["PREDICTRET"], squared=False)
  print("RMSE[%s]: %0.2f" % (i,rmse[i]))
# Out:
# RMSE[BGR001]: 2.36
# RMSE[BGR002]: 1.78
# RMSE[BGR003]: 3.24
# RMSE[BGR004]: 1.76
# RMSE[BGR005]: 2.46
# RMSE[BGR006]: 1.51
# RMSE[BGR007]: 3.36
# RMSE[BGR008]: 0.93
# RMSE[BGR009]: 1.86
# RMSE[BGR010]: 1.80
# RMSE[BGR011]: 0.76
# RMSE[BGR012]: 1.21
# RMSE[BGR014]: 2.88
# RMSE[BGR015]: 1.53
# RMSE[BGR016]: 3.16
# RMSE[BGR017]: 2.64
# RMSE[BGR018]: 4.07
# RMSE[BGR019]: 2.36
# RMSE[BGR020]: 2.28
# RMSE[BGR021]: 3.05
# RMSE[BGR022]: 2.11
# RMSE[BGR023]: 2.19
# RMSE[BGR026]: 2.75
# RMSE[BGR027]: 1.63
# RMSE[BGR028]: 2.71
# RMSE[BGR029]: 1.82
# RMSE[BGR030]: 2.60
# RMSE[BGR031]: 2.76
# RMSE[BGR032]: 2.64
# RMSE[BGR034]: 2.12
# RMSE[BGR035]: 3.38
# RMSE[BGR036]: 2.05
# RMSE[BGR037]: 1.85
# RMSE[BGR039]: 2.29
# RMSE[BGR040]: 1.67
# RMSE[BGR041]: 2.41
# RMSE[BGR042]: 2.02
# RMSE[BGR043]: 2.01
# RMSE[BGR045]: 1.88
# RMSE[BGR052]: 1.63
# RMSE[BGR053]: 1.10
# RMSE[BGR054]: 2.05
# RMSE[BGR055]: 2.33
# RMSE[BGR059]: 1.43
# RMSE[BGR063]: 2.71
# RMSE[BGR065]: 3.79
# RMSE[BGR066]: 1.31
# RMSE[BGR067]: 0.76
# RMSE[BGR070]: 2.19
# RMSE[BGR071]: 1.16
# RMSE[BGR073]: 1.50
# RMSE[BGR074]: 2.94
# RMSE[BGR075]: 3.80
# RMSE[BGR076]: 3.52
# RMSE[BGR079]: 2.22
# RMSE[BGR080]: 2.26
# RMSE[BGR084]: 3.44
# RMSE[BGR085]: 2.94
# RMSE[BGR086]: 1.36
# RMSE[BGR089]: 2.07
# RMSE[BGR091]: 2.38
# RMSE[BGR124]: 3.77
# RMSE[BGR125]: 2.06
# RMSE[BGR133]: 4.84
# RMSE[BGR134]: 2.08
# RMSE[BGR135]: 1.87
# RMSE[BGR136]: 2.00
# RMSE[BGR137]: 1.72
# RMSE[BGR138]: 1.61
# RMSE[BGR139]: 0.82
# RMSE[BGR140]: 2.55
# RMSE[BGR141]: 1.07
# RMSE[BGR142]: 1.63
# RMSE[BGR143]: 1.19
# RMSE[BGR144]: 1.34
# RMSE[BGR145]: 1.23
# RMSE[BGR146]: 0.00
# RMSE[BGR147]: 2.57
# RMSE[BGR148]: 1.14
# RMSE[BGR149]: 1.06
# RMSE[BGR150]: 2.57
# RMSE[BGR151]: 0.33
# RMSE[BGR152]: 1.18
# RMSE[BGR153]: 0.87
# RMSE[BGR154]: 1.86
# RMSE[BGR155]: 6.04
# RMSE[BGR156]: 5.29
# RMSE[BGR157]: 0.00
# RMSE[BGR158]: 0.36
# RMSE[BGR159]: 2.60
# RMSE[BGR160]: 0.24
# RMSE[BGR161]: 1.18
# RMSE[BGR162]: 0.45
# RMSE[BGR163]: 0.47
# RMSE[BGR165]: 3.54
# RMSE[BGR166]: 2.57
# RMSE[BGR167]: 1.60
# RMSE[BGR168]: 1.42
# RMSE[BGR169]: 2.04
# RMSE[BGR170]: 5.02
# RMSE[BGR171]: 1.66
# RMSE[BGR172]: 4.16
# RMSE[BGR173]: 1.33
# RMSE[BGR174]: 0.92
# RMSE[BGR175]: 0.00
# RMSE[BGR176]: 0.62
# RMSE[BGR177]: 2.29
# RMSE[CPN001]: 1.95
# RMSE[CPN002]: 2.87
# RMSE[CPN005]: 1.43
# RMSE[CPN006]: 1.83
# RMSE[CPN007]: 3.15
# RMSE[CPN009]: 1.64
# RMSE[CPN010]: 1.63
# RMSE[CPN011]: 1.23
# RMSE[CPN012]: 0.00
# RMSE[CPN014]: 2.48
# RMSE[CPN015]: 1.78
# RMSE[CPN017]: 0.54
# RMSE[CPN018]: 1.88
# RMSE[CPN021]: 2.19
# RMSE[CPN022]: 1.45
# RMSE[CPN024]: 2.88
# RMSE[CPN025]: 3.07
# RMSE[CPN026]: 2.20
# RMSE[CPN028]: 3.76
# RMSE[CPN029]: 1.51
# RMSE[CPN031]: 0.89
# RMSE[CPN033]: 2.04
# RMSE[CPN035]: 1.67
# RMSE[CPN036]: 0.97
# RMSE[CPN037]: 0.58
# RMSE[CPN038]: 0.68
# RMSE[CPN040]: 1.32
# RMSE[CPN042]: 1.80
# RMSE[CPN043]: 1.19
# RMSE[CPN045]: 1.28
# RMSE[CPN046]: 2.33
# RMSE[CPN047]: 0.68
# RMSE[CPN051]: 0.91
# RMSE[CPN052]: 1.10
# RMSE[CPN053]: 1.21
# RMSE[CPN054]: 1.27
# RMSE[CPN055]: 3.36
# RMSE[CPN056]: 2.42
# RMSE[CPN059]: 2.21
# RMSE[CPN064]: 3.75
# RMSE[CPN065]: 1.94
# RMSE[CPN066]: 1.20
# RMSE[CPN070]: 0.00
# RMSE[CPN071]: 0.69
# RMSE[CPN072]: 1.10
# RMSE[CPN076]: 2.68
# RMSE[CPN078]: 0.70
# RMSE[CPN079]: 1.36
# RMSE[CPN080]: 1.34
# RMSE[CPN081]: 1.84
# RMSE[CPN082]: 1.45
# RMSE[CPN083]: 0.74
# RMSE[CPN084]: 0.87
# RMSE[CPN085]: 2.66
# RMSE[CPN086]: 1.34
# RMSE[CPN087]: 1.97
# RMSE[CPN088]: 1.87
# RMSE[CPN089]: 3.37
# RMSE[CPN090]: 2.25
# RMSE[CPN091]: 1.20
# RMSE[CPN092]: 2.22
# RMSE[DMG001]: 3.55
# RMSE[DMG002]: 0.71
# RMSE[DMG003]: 1.63
# RMSE[DMG004]: 2.14
# RMSE[DMG005]: 2.45
# RMSE[DMG006]: 1.07
# RMSE[DMG007]: 2.68
# RMSE[DMG008]: 2.12
# RMSE[DMG009]: 0.57
# RMSE[DMG010]: 0.77
# RMSE[DMG011]: 3.60
# RMSE[DMG012]: 3.08
# RMSE[DMG013]: 1.26
# RMSE[DMG014]: 1.20
# RMSE[DMG015]: 1.53
# RMSE[DMG016]: 0.67
# RMSE[DMG017]: 1.13
# RMSE[DMG018]: 3.08
# RMSE[DMG019]: 1.41
# RMSE[DMG020]: 1.87
# RMSE[DMG022]: 1.70
# RMSE[DMG024]: 3.05
# RMSE[DMG025]: 0.99
# RMSE[DMG026]: 1.24
# RMSE[DMG027]: 0.98
# RMSE[DMG028]: 1.38
# RMSE[DMG029]: 1.07
# RMSE[DMG030]: 1.70
# RMSE[DMG031]: 1.05
# RMSE[DMG032]: 1.97
# RMSE[DMG033]: 2.52
# RMSE[DMG034]: 0.76
# RMSE[DMG035]: 0.80
# RMSE[DMG036]: 2.38
# RMSE[DMG037]: 1.06
# RMSE[DMG038]: 1.47
# RMSE[DMG040]: 0.74
# RMSE[DMG041]: 2.23
# RMSE[DMG044]: 2.22
# RMSE[DMG047]: 0.98
# RMSE[DMG048]: 0.74
# RMSE[DMG049]: 0.60
# RMSE[DMG051]: 1.43
# RMSE[DMG053]: 2.70
# RMSE[DMG054]: 1.94
# RMSE[DMG069]: 1.53
# RMSE[DMG075]: 1.79
# RMSE[DMG076]: 1.75
# RMSE[DMG077]: 4.09
# RMSE[DMG078]: 1.10
# RMSE[DMG079]: 3.40
# RMSE[DMG080]: 1.07
# RMSE[DMG081]: 0.50
# RMSE[DMG082]: 2.67
# RMSE[DMG083]: 2.56
# RMSE[DMG084]: 1.10
# RMSE[DMG085]: 2.98
# RMSE[DMG086]: 3.58
# RMSE[DMG087]: 0.00
# RMSE[DMG088]: 0.89
# RMSE[DMG089]: 2.40
# RMSE[DMG090]: 3.00
# RMSE[DMG091]: 1.39
# RMSE[DMG092]: 1.33
# RMSE[DMG093]: 1.19
# RMSE[DMG094]: 1.27
# RMSE[DMG095]: 1.55
# RMSE[DMG100]: 1.04
# RMSE[DMG101]: 1.49
# RMSE[DMG102]: 1.72
# RMSE[DMG103]: 1.00
# RMSE[DMG104]: 2.68
# RMSE[DMG105]: 0.97
# RMSE[DMG106]: 2.45
# RMSE[DMG107]: 1.36
# RMSE[DMG96]: 0.82
# RMSE[DMG97]: 1.33
# RMSE[DMG98]: 2.41
# RMSE[DMG99]: 1.35
# RMSE[DPK001]: 2.88
# RMSE[DPK002]: 1.47
# RMSE[DPK003]: 1.80
# RMSE[DPK004]: 3.42
# RMSE[DPK006]: 1.27
# RMSE[DPK007]: 0.94
# RMSE[DPK008]: 1.60
# RMSE[DPK009]: 2.22
# RMSE[DPK010]: 2.91
# RMSE[DPK011]: 1.54
# RMSE[DPK013]: 1.84
# RMSE[DPK015]: 1.11
# RMSE[DPK016]: 1.62
# RMSE[DPK017]: 0.96
# RMSE[DPK018]: 1.31
# RMSE[DPK019]: 3.12
# RMSE[DPK020]: 0.89
# RMSE[DPK021]: 1.20
# RMSE[DPK023]: 2.49
# RMSE[DPK024]: 0.98
# RMSE[DPK026]: 1.92
# RMSE[DPK027]: 0.85
# RMSE[DPK029]: 0.85
# RMSE[DPK030]: 1.32
# RMSE[DPK031]: 0.71
# RMSE[DPK032]: 1.72
# RMSE[DPK033]: 1.65
# RMSE[DPK034]: 3.54
# RMSE[DPK035]: 1.60
# RMSE[DPK038]: 3.04
# RMSE[DPK039]: 1.08
# RMSE[DPK040]: 0.75
# RMSE[DPK043]: 1.23
# RMSE[DPK055]: 4.98
# RMSE[DPK056]: 1.81
# RMSE[DPK057]: 2.29
# RMSE[DPK058]: 1.59
# RMSE[DPK059]: 1.12
# RMSE[DPK060]: 2.38
# RMSE[DPK061]: 4.68
# RMSE[DPK062]: 1.95
# RMSE[DPK063]: 1.41
# RMSE[DPK064]: 0.95
# RMSE[DPK065]: 2.22
# RMSE[DPK066]: 0.93
# RMSE[DPK067]: 3.52
# RMSE[DPK068]: 3.06
# RMSE[DPK069]: 2.03
# RMSE[DPK070]: 3.61
# RMSE[DPK071]: 0.38
# RMSE[DPK072]: 0.00
# RMSE[LWL042]: 1.44
# RMSE[LWL047]: 2.04
# RMSE[LWL048]: 2.39
# RMSE[LWL049]: 1.92
# RMSE[LWL050]: 1.60
# RMSE[LWL051]: 2.44
# RMSE[LWL052]: 2.83
# RMSE[LWL053]: 2.05
# RMSE[LWL054]: 3.06
# RMSE[LWL056]: 1.10
# RMSE[LWL058]: 3.10
# RMSE[LWL060]: 2.11
# RMSE[LWL061]: 2.36
# RMSE[LWL062]: 3.81
# RMSE[LWL074]: 5.23
# RMSE[LWL075]: 4.28
# RMSE[LWL076]: 2.26
# RMSE[LWL077]: 0.35
# RMSE[LWL093]: 3.27
# RMSE[LWL097]: 2.54
# RMSE[LWL106]: 7.29
# RMSE[LWL112]: 3.52
# RMSE[LWL126]: 2.72
# RMSE[LWL133]: 2.08
# RMSE[LWL134]: 1.90
# RMSE[LWL135]: 2.93
# RMSE[LWL136]: 1.51
# RMSE[LWL137]: 4.18
# RMSE[LWL138]: 5.42
# RMSE[LWL139]: 3.32
# RMSE[LWL140]: 3.65
# RMSE[LWL141]: 2.13
# RMSE[LWL142]: 4.58
# RMSE[LWL143]: 0.67
# RMSE[LWL144]: 0.55
# RMSE[LWL156]: 0.00
# RMSE[SDB001]: 3.01
# RMSE[SDB003]: 1.13
# RMSE[SDB005]: 3.00
# RMSE[SDB006]: 3.98
# RMSE[SDB007]: 1.04
# RMSE[SDB008]: 3.64
# RMSE[SDB009]: 1.20
# RMSE[SDB010]: 5.10
# RMSE[SDB011]: 1.91
# RMSE[SDB012]: 2.83
# RMSE[SDB014]: 2.45
# RMSE[SDB015]: 1.01
# RMSE[SDB020]: 3.67
# RMSE[SDB024]: 5.33
# RMSE[SDB025]: 3.43
# RMSE[SDB027]: 1.70
# RMSE[SDB028]: 1.48
# RMSE[SDB029]: 1.72
# RMSE[SDB030]: 4.62
# RMSE[SDB031]: 3.58
# RMSE[SDB032]: 3.91
# RMSE[SDB033]: 1.72
# RMSE[SDB035]: 1.39
# RMSE[SDB042]: 0.94
# RMSE[SDB043]: 1.19
# RMSE[SDB044]: 1.93
# RMSE[SDB045]: 1.46
# RMSE[SDB046]: 1.79
# RMSE[SDB047]: 2.21
# RMSE[SDB048]: 3.13
# RMSE[SDB049]: 0.00
# RMSE[SDB050]: 1.43
# RMSE[SDB051]: 5.12
# RMSE[SDB052]: 2.76
# RMSE[SDB053]: 5.06
# RMSE[SDB054]: 1.55
# RMSE[SDB055]: 0.24
# RMSE[SDB056]: 2.42
# RMSE[SDB057]: 1.58
# RMSE[SDB058]: 4.95
# RMSE[SDB059]: 1.92
# RMSE[SDB060]: 2.06
# RMSE[SDB061]: 2.84
# RMSE[SDB062]: 2.27
# RMSE[SDB063]: 0.56
# RMSE[SDB065]: 5.01
# RMSE[SDB142]: 4.49
# RMSE[SDB143]: 0.72
# RMSE[SDB144]: 1.62
# RMSE[SDB64]: 0.00
# RMSE[SMI001]: 1.28
# RMSE[SMI002]: 0.98
# RMSE[SMI003]: 1.12
# RMSE[SMI004]: 0.99
# RMSE[SMI005]: 1.44
# RMSE[SMI006]: 1.40
# RMSE[SMI007]: 0.65
# RMSE[SMI008]: 2.23
# RMSE[SMI009]: 2.87
# RMSE[SMI010]: 1.73
# RMSE[SMI011]: 0.77
# RMSE[SMI012]: 1.15
# RMSE[SMI013]: 0.74
# RMSE[SMI014]: 1.93
# RMSE[SMI015]: 2.91
# RMSE[SMI016]: 1.25
# RMSE[SMI017]: 1.65
# RMSE[SMI018]: 1.85
# RMSE[SMI019]: 1.21
# RMSE[SMI020]: 1.89
# RMSE[SMI021]: 1.27
# RMSE[SMI022]: 1.34
# RMSE[SMI023]: 1.40
# RMSE[SMI024]: 1.81
# RMSE[SMI025]: 0.88
# RMSE[SMI026]: 8.71
# RMSE[SMI027]: 1.36
# RMSE[SMI028]: 0.87
# RMSE[SMI029]: 3.23
# RMSE[SMI030]: 1.61
# RMSE[SMI031]: 0.98
# RMSE[SMI032]: 2.41
# RMSE[SMI033]: 1.51
# RMSE[SMI034]: 0.58
# RMSE[SMI035]: 0.64
# RMSE[SMI036]: 0.96
# RMSE[SMI037]: 1.30
# RMSE[SMI038]: 2.74
# RMSE[SMI039]: 0.83
# RMSE[SMI040]: 1.37
# RMSE[SMI041]: 1.07
# RMSE[SMI042]: 1.09
# RMSE[SMI043]: 1.44
# RMSE[SMI044]: 1.70
# RMSE[SMI046]: 0.67
# RMSE[SMI047]: 3.25
# RMSE[SMI048]: 3.53
# RMSE[SMI049]: 0.88
# RMSE[SMI050]: 1.14
# RMSE[SMI051]: 2.13
# RMSE[SMI053]: 2.61
# RMSE[SMI057]: 1.07
# RMSE[SMI060]: 2.02
# RMSE[SMI062]: 0.93
# RMSE[SMI063]: 1.17
# RMSE[SMI065]: 1.07
# RMSE[SMI066]: 2.12
# RMSE[SMI067]: 1.40
# RMSE[SMI068]: 0.71
# RMSE[SMI070]: 1.26
# RMSE[SMI071]: 0.87
# RMSE[SMI072]: 1.78
# RMSE[SMI073]: 2.59
# RMSE[SMI075]: 0.78
# RMSE[SMI076]: 0.88
# RMSE[SMI077]: 3.55
# RMSE[SMI078]: 1.90
# RMSE[SMI079]: 3.53
# RMSE[SMI080]: 1.46
# RMSE[SMI081]: 1.98
# RMSE[SMI082]: 0.96
# RMSE[SMI083]: 1.08
# RMSE[SMI084]: 1.83
# RMSE[SMI086]: 1.12
# RMSE[SMI088]: 2.70
# RMSE[SMI093]: 3.12
# RMSE[SMI099]: 1.22
# RMSE[SMI100]: 1.03
# RMSE[SMI102]: 2.51
# RMSE[SMI103]: 0.55
# RMSE[SMI107]: 2.18
# RMSE[SMI108]: 3.00
# RMSE[SMI113]: 2.25
# RMSE[SMI114]: 1.05
# RMSE[SMI115]: 0.91
# RMSE[SMI116]: 1.46
# RMSE[SMI118]: 2.76
# RMSE[SMI119]: 1.06
# RMSE[SMI120]: 1.55
# RMSE[SMI121]: 1.92
# RMSE[SMI122]: 0.74
# RMSE[SMI123]: 2.60
# RMSE[SMI124]: 1.02
# RMSE[SMI125]: 1.53
# RMSE[SMI126]: 2.11
# RMSE[SMI127]: 2.28
# RMSE[SMI128]: 1.30
# RMSE[SMI129]: 2.81
# RMSE[SMI130]: 2.09
# RMSE[SMI131]: 0.57
# RMSE[SMI132]: 2.22
# RMSE[SMI133]: 2.71
# RMSE[SMI134]: 1.48
# RMSE[SMI135]: 4.24
# RMSE[SMI136]: 1.85
# RMSE[SMI137]: 2.07
# RMSE[SMI138]: 0.56
# RMSE[SMI139]: 0.88
# RMSE[SMI140]: 0.75
# RMSE[SMI141]: 3.58
# RMSE[SMI142]: 4.02
# RMSE[SMI143]: 3.09
# RMSE[SMI144]: 1.03
# RMSE[SMI145]: 2.08
# RMSE[SMI146]: 1.41
# RMSE[SMI147]: 1.08
# RMSE[SMI148]: 1.31
# RMSE[SMI149]: 2.05
# RMSE[SMI150]: 2.00
# RMSE[SMI151]: 0.76
# RMSE[SMI152]: 1.97
# RMSE[SMI153]: 1.65
# RMSE[SMI154]: 2.30
# RMSE[SMI155]: 1.44
# RMSE[SMI156]: 1.53
# RMSE[SMI157]: 1.53
# RMSE[SMI158]: 0.00
# RMSE[SMI159]: 1.83
# RMSE[SMI160]: 1.83
# RMSE[SMI161]: 4.17
# RMSE[SMI162]: 1.78
# RMSE[SMI163]: 1.19
# RMSE[SMI164]: 1.80
# RMSE[SMI165]: 1.53
# RMSE[SMI166]: 2.14
# RMSE[SMI167]: 1.95
# RMSE[SMI168]: 1.94
# RMSE[SMI169]: 0.89
# RMSE[SMI170]: 1.69
# RMSE[SMI171]: 2.11
# RMSE[SMI172]: 1.11
# RMSE[SMI173]: 1.73
# RMSE[SMI174]: 2.28
# RMSE[SMI175]: 3.09
# RMSE[SMI176]: 0.98
# RMSE[SMI177]: 2.48
# RMSE[SMI178]: 2.55
# RMSE[SMI179]: 1.06
# RMSE[SMI180]: 1.86
# RMSE[SMI181]: 1.06
# RMSE[SMI182]: 0.55
# RMSE[SMI183]: 0.00
# RMSE[SMI184]: 2.08
# RMSE[SMI185]: 1.37
# RMSE[SMI186]: 2.15
# RMSE[SMI187]: 0.71
# RMSE[SMI188]: 2.58
# RMSE[SMI189]: 0.92
# RMSE[SMI190]: 0.93
# RMSE[SMI191]: 2.19
# RMSE[SMI192]: 1.56
# RMSE[SMI193]: 1.80
# RMSE[SMI194]: 0.71
# RMSE[SMI195]: 3.26
# RMSE[SMI196]: 1.41
# RMSE[SMI197]: 0.25
# RMSE[SMI198]: 0.67
# RMSE[SMI199]: 3.12
# RMSE[SMI200]: 0.36
# RMSE[SMI201]: 1.47
# RMSE[SMI202]: 0.81
# RMSE[SMI203]: 0.84
# RMSE[SMI204]: 1.00
# RMSE[SMI205]: 1.34
# RMSE[SMI206]: 1.57
# RMSE[SMI207]: 1.29
# RMSE[SMI208]: 0.68
# RMSE[SMI209]: 0.56
# RMSE[SMI210]: 0.00
# RMSE[SMI211]: 1.61
# RMSE[SMI212]: 1.25
# RMSE[SMI213]: 0.79
# RMSE[SMI214]: 1.98
# RMSE[SMI215]: 2.44
# RMSE[SMI216]: 0.43
# RMSE[SMI217]: 0.00
# RMSE[Z001]: 0.00

# %%
#Averaging The RMSE Score
totalValueMSE = 0

for i in dataBasedOnAllCustomerClean:
  totalValueMSE = totalValueMSE + rmse[i]

avgValue = totalValueMSE/len(dataBasedOnAllCustomerClean)
print(avgValue)
# Out:
# 1.8884858757587966

# %% [markdown]
# ##R-Squared Score

# %%
#Calculating The R-Squared Score for All Models
r2 = {}

for i in dataBasedOnAllCustomerClean:
  r2[i] = r2_score(y[i], dataBasedOnAllCustomerClean[i]["PREDICTRET"])
  print("R2 Score[%s]: %0.2f" % (i,r2[i]))
# Out:
# R2 Score[BGR001]: -0.34
# R2 Score[BGR002]: -0.48
# R2 Score[BGR003]: -0.45
# R2 Score[BGR004]: -0.25
# R2 Score[BGR005]: -0.49
# R2 Score[BGR006]: -0.21
# R2 Score[BGR007]: -0.58
# R2 Score[BGR008]: -0.25
# R2 Score[BGR009]: -0.36
# R2 Score[BGR010]: -0.44
# R2 Score[BGR011]: -0.31
# R2 Score[BGR012]: -0.19
# R2 Score[BGR014]: -0.29
# R2 Score[BGR015]: -0.15
# R2 Score[BGR016]: -0.47
# R2 Score[BGR017]: -0.32
# R2 Score[BGR018]: -0.80
# R2 Score[BGR019]: -0.50
# R2 Score[BGR020]: -0.44
# R2 Score[BGR021]: -0.40
# R2 Score[BGR022]: -0.40
# R2 Score[BGR023]: -0.22
# R2 Score[BGR026]: -0.70
# R2 Score[BGR027]: -0.37
# R2 Score[BGR028]: -0.66
# R2 Score[BGR029]: -0.35
# R2 Score[BGR030]: -1.37
# R2 Score[BGR031]: -0.37
# R2 Score[BGR032]: -0.31
# R2 Score[BGR034]: -0.57
# R2 Score[BGR035]: -0.83
# R2 Score[BGR036]: -0.41
# R2 Score[BGR037]: -0.25
# R2 Score[BGR039]: -1.11
# R2 Score[BGR040]: -1.76
# R2 Score[BGR041]: -1.03
# R2 Score[BGR042]: -0.33
# R2 Score[BGR043]: -0.43
# R2 Score[BGR045]: -0.45
# R2 Score[BGR052]: -0.39
# R2 Score[BGR053]: -0.10
# R2 Score[BGR054]: -0.31
# R2 Score[BGR055]: -0.38
# R2 Score[BGR059]: -0.34
# R2 Score[BGR063]: -0.30
# R2 Score[BGR065]: -1.16
# R2 Score[BGR066]: -0.16
# R2 Score[BGR067]: -0.48
# R2 Score[BGR070]: -0.77
# R2 Score[BGR071]: -0.19
# R2 Score[BGR073]: -0.39
# R2 Score[BGR074]: -0.75
# R2 Score[BGR075]: -0.69
# R2 Score[BGR076]: -0.80
# R2 Score[BGR079]: -0.48
# R2 Score[BGR080]: -0.56
# R2 Score[BGR084]: -0.97
# R2 Score[BGR085]: -0.68
# R2 Score[BGR086]: -0.16
# R2 Score[BGR089]: -0.37
# R2 Score[BGR091]: -0.27
# R2 Score[BGR124]: -2.41
# R2 Score[BGR125]: -0.47
# R2 Score[BGR133]: -1.02
# R2 Score[BGR134]: -0.44
# R2 Score[BGR135]: -0.58
# R2 Score[BGR136]: -0.83
# R2 Score[BGR137]: -0.41
# R2 Score[BGR138]: -0.10
# R2 Score[BGR139]: -0.13
# R2 Score[BGR140]: -0.42
# R2 Score[BGR141]: -0.16
# R2 Score[BGR142]: -0.32
# R2 Score[BGR143]: -0.24
# R2 Score[BGR144]: -0.49
# R2 Score[BGR145]: -0.17
# R2 Score[BGR146]: 1.00
# R2 Score[BGR147]: -0.97
# R2 Score[BGR148]: -0.23
# R2 Score[BGR149]: -0.22
# R2 Score[BGR150]: -0.64
# R2 Score[BGR151]: 0.21
# R2 Score[BGR152]: -0.20
# R2 Score[BGR153]: 0.00
# R2 Score[BGR154]: -0.31
# R2 Score[BGR155]: -1.29
# R2 Score[BGR156]: -1.03
# R2 Score[BGR157]: 1.00
# R2 Score[BGR158]: 0.00
# R2 Score[BGR159]: -1.67
# R2 Score[BGR160]: 0.00
# R2 Score[BGR161]: -0.34
# R2 Score[BGR162]: 0.00
# R2 Score[BGR163]: 0.00
# R2 Score[BGR165]: -1.00
# R2 Score[BGR166]: -0.10
# R2 Score[BGR167]: -0.89
# R2 Score[BGR168]: -0.64
# R2 Score[BGR169]: -0.58
# R2 Score[BGR170]: -0.21
# R2 Score[BGR171]: -0.65
# R2 Score[BGR172]: -1.20
# R2 Score[BGR173]: -0.41
# R2 Score[BGR174]: -0.58
# R2 Score[BGR175]: 1.00
# R2 Score[BGR176]: -1.35
# R2 Score[BGR177]: -0.97
# R2 Score[CPN001]: -0.54
# R2 Score[CPN002]: -0.36
# R2 Score[CPN005]: -0.37
# R2 Score[CPN006]: -0.66
# R2 Score[CPN007]: -0.69
# R2 Score[CPN009]: -0.42
# R2 Score[CPN010]: -0.35
# R2 Score[CPN011]: -0.23
# R2 Score[CPN012]: 1.00
# R2 Score[CPN014]: -0.19
# R2 Score[CPN015]: -0.36
# R2 Score[CPN017]: -5.97
# R2 Score[CPN018]: -0.73
# R2 Score[CPN021]: -0.36
# R2 Score[CPN022]: -0.78
# R2 Score[CPN024]: -0.07
# R2 Score[CPN025]: -0.41
# R2 Score[CPN026]: -0.50
# R2 Score[CPN028]: -0.23
# R2 Score[CPN029]: -0.40
# R2 Score[CPN031]: -0.41
# R2 Score[CPN033]: -0.54
# R2 Score[CPN035]: -0.27
# R2 Score[CPN036]: -0.42
# R2 Score[CPN037]: -3.70
# R2 Score[CPN038]: -0.98
# R2 Score[CPN040]: -0.41
# R2 Score[CPN042]: -0.08
# R2 Score[CPN043]: -0.49
# R2 Score[CPN045]: -0.23
# R2 Score[CPN046]: -0.43
# R2 Score[CPN047]: -1.00
# R2 Score[CPN051]: -0.30
# R2 Score[CPN052]: -0.29
# R2 Score[CPN053]: -0.36
# R2 Score[CPN054]: -0.35
# R2 Score[CPN055]: -0.21
# R2 Score[CPN056]: -0.49
# R2 Score[CPN059]: -0.65
# R2 Score[CPN064]: -0.86
# R2 Score[CPN065]: -0.30
# R2 Score[CPN066]: -0.36
# R2 Score[CPN070]: nan
# R2 Score[CPN071]: -0.80
# R2 Score[CPN072]: -0.41
# R2 Score[CPN076]: -0.61
# R2 Score[CPN078]: -0.63
# R2 Score[CPN079]: -1.33
# R2 Score[CPN080]: -0.32
# R2 Score[CPN081]: -0.86
# R2 Score[CPN082]: -0.46
# R2 Score[CPN083]: -0.59
# R2 Score[CPN084]: -0.09
# R2 Score[CPN085]: -0.95
# R2 Score[CPN086]: -0.40
# R2 Score[CPN087]: -0.26
# R2 Score[CPN088]: -0.61
# R2 Score[CPN089]: -0.89
# R2 Score[CPN090]: -0.55
# R2 Score[CPN091]: -0.60
# R2 Score[CPN092]: -0.80
# R2 Score[DMG001]: -0.40
# R2 Score[DMG002]: -1.67
# R2 Score[DMG003]: -0.33
# R2 Score[DMG004]: -0.31
# R2 Score[DMG005]: -0.14
# R2 Score[DMG006]: -0.25
# R2 Score[DMG007]: -0.92
# R2 Score[DMG008]: -0.41
# R2 Score[DMG009]: -3.43
# R2 Score[DMG010]: -0.54
# R2 Score[DMG011]: -0.56
# R2 Score[DMG012]: -0.30
# R2 Score[DMG013]: -0.27
# R2 Score[DMG014]: -0.58
# R2 Score[DMG015]: -0.49
# R2 Score[DMG016]: -1.10
# R2 Score[DMG017]: -0.33
# R2 Score[DMG018]: -0.29
# R2 Score[DMG019]: -0.13
# R2 Score[DMG020]: -0.22
# R2 Score[DMG022]: -0.44
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# R2 Score[DMG024]: -0.43
# R2 Score[DMG025]: -0.43
# R2 Score[DMG026]: -0.52
# R2 Score[DMG027]: -0.35
# R2 Score[DMG028]: -0.36
# R2 Score[DMG029]: -0.30
# R2 Score[DMG030]: -0.15
# R2 Score[DMG031]: -0.40
# R2 Score[DMG032]: -0.48
# R2 Score[DMG033]: -0.42
# R2 Score[DMG034]: -0.48
# R2 Score[DMG035]: -0.14
# R2 Score[DMG036]: -0.17
# R2 Score[DMG037]: -0.44
# R2 Score[DMG038]: -0.28
# R2 Score[DMG040]: -0.60
# R2 Score[DMG041]: -0.27
# R2 Score[DMG044]: -0.42
# R2 Score[DMG047]: -0.27
# R2 Score[DMG048]: -0.78
# R2 Score[DMG049]: -0.88
# R2 Score[DMG051]: -0.12
# R2 Score[DMG053]: -0.63
# R2 Score[DMG054]: -2.00
# R2 Score[DMG069]: -0.15
# R2 Score[DMG075]: -0.20
# R2 Score[DMG076]: -0.59
# R2 Score[DMG077]: -0.57
# R2 Score[DMG078]: -0.32
# R2 Score[DMG079]: -0.42
# R2 Score[DMG080]: -0.40
# R2 Score[DMG081]: 0.00
# R2 Score[DMG082]: -0.79
# R2 Score[DMG083]: -0.32
# R2 Score[DMG084]: -0.19
# R2 Score[DMG085]: -0.78
# R2 Score[DMG086]: -1.17
# R2 Score[DMG087]: nan
# R2 Score[DMG088]: -0.83
# R2 Score[DMG089]: -0.47
# R2 Score[DMG090]: -1.09
# R2 Score[DMG091]: 0.04
# R2 Score[DMG092]: -0.60
# R2 Score[DMG093]: -0.29
# R2 Score[DMG094]: -0.32
# R2 Score[DMG095]: -0.67
# R2 Score[DMG100]: -0.47
# R2 Score[DMG101]: -1.01
# R2 Score[DMG102]: -0.49
# R2 Score[DMG103]: -0.48
# R2 Score[DMG104]: -0.72
# R2 Score[DMG105]: -0.28
# R2 Score[DMG106]: -0.78
# R2 Score[DMG107]: -0.15
# R2 Score[DMG96]: -0.66
# R2 Score[DMG97]: -0.60
# R2 Score[DMG98]: -1.92
# R2 Score[DMG99]: -0.17
# R2 Score[DPK001]: -0.16
# R2 Score[DPK002]: -0.21
# R2 Score[DPK003]: -0.44
# R2 Score[DPK004]: -0.26
# R2 Score[DPK006]: -0.17
# R2 Score[DPK007]: -0.26
# R2 Score[DPK008]: -0.52
# R2 Score[DPK009]: -1.25
# R2 Score[DPK010]: -0.30
# R2 Score[DPK011]: -0.62
# R2 Score[DPK013]: -0.41
# R2 Score[DPK015]: -0.18
# R2 Score[DPK016]: -0.16
# R2 Score[DPK017]: -0.50
# R2 Score[DPK018]: -0.34
# R2 Score[DPK019]: -0.16
# R2 Score[DPK020]: -0.33
# R2 Score[DPK021]: -0.24
# R2 Score[DPK023]: -0.33
# R2 Score[DPK024]: -0.45
# R2 Score[DPK026]: -1.30
# R2 Score[DPK027]: -0.57
# R2 Score[DPK029]: -0.30
# R2 Score[DPK030]: -0.12
# R2 Score[DPK031]: -0.74
# R2 Score[DPK032]: -0.19
# R2 Score[DPK033]: -0.14
# R2 Score[DPK034]: -1.37
# R2 Score[DPK035]: -0.22
# R2 Score[DPK038]: -0.60
# R2 Score[DPK039]: -0.14
# R2 Score[DPK040]: -0.57
# R2 Score[DPK043]: -0.14
# R2 Score[DPK055]: -1.02
# R2 Score[DPK056]: -0.07
# R2 Score[DPK057]: -1.10
# R2 Score[DPK058]: -0.43
# R2 Score[DPK059]: -0.67
# R2 Score[DPK060]: -0.33
# R2 Score[DPK061]: -0.94
# R2 Score[DPK062]: -0.41
# R2 Score[DPK063]: -1.25
# R2 Score[DPK064]: -0.49
# R2 Score[DPK065]: -0.76
# R2 Score[DPK066]: -0.38
# R2 Score[DPK067]: -1.09
# R2 Score[DPK068]: -2.82
# R2 Score[DPK069]: -0.73
# R2 Score[DPK070]: -0.69
# R2 Score[DPK071]: -0.09
# R2 Score[DPK072]: nan
# R2 Score[LWL042]: -0.14
# R2 Score[LWL047]: -0.75
# R2 Score[LWL048]: -0.73
# R2 Score[LWL049]: -0.67
# R2 Score[LWL050]: -0.52
# R2 Score[LWL051]: -0.89
# R2 Score[LWL052]: -0.83
# R2 Score[LWL053]: -0.62
# R2 Score[LWL054]: -0.50
# R2 Score[LWL056]: -0.49
# R2 Score[LWL058]: -0.81
# R2 Score[LWL060]: -1.24
# R2 Score[LWL061]: -0.43
# R2 Score[LWL062]: -0.59
# R2 Score[LWL074]: -0.29
# R2 Score[LWL075]: -0.54
# R2 Score[LWL076]: -0.30
# R2 Score[LWL077]: 0.00
# R2 Score[LWL093]: -0.30
# R2 Score[LWL097]: -0.60
# R2 Score[LWL106]: -0.64
# R2 Score[LWL112]: -0.72
# R2 Score[LWL126]: -0.25
# R2 Score[LWL133]: -0.89
# R2 Score[LWL134]: -0.61
# R2 Score[LWL135]: -1.26
# R2 Score[LWL136]: -0.33
# R2 Score[LWL137]: -0.72
# R2 Score[LWL138]: -2.75
# R2 Score[LWL139]: -0.60
# R2 Score[LWL140]: -0.55
# R2 Score[LWL141]: -0.49
# R2 Score[LWL142]: -4.46
# R2 Score[LWL143]: -0.04
# R2 Score[LWL144]: -0.16
# R2 Score[LWL156]: nan
# R2 Score[SDB001]: -0.54
# R2 Score[SDB003]: -0.27
# R2 Score[SDB005]: -1.09
# R2 Score[SDB006]: -0.66
# R2 Score[SDB007]: -0.28
# R2 Score[SDB008]: -0.81
# R2 Score[SDB009]: -0.28
# R2 Score[SDB010]: -0.21
# R2 Score[SDB011]: -0.68
# R2 Score[SDB012]: -0.64
# R2 Score[SDB014]: -0.87
# R2 Score[SDB015]: -0.41
# R2 Score[SDB020]: -0.29
# R2 Score[SDB024]: -0.17
# R2 Score[SDB025]: -0.22
# R2 Score[SDB027]: -0.51
# R2 Score[SDB028]: -0.41
# R2 Score[SDB029]: -0.73
# R2 Score[SDB030]: -0.79
# R2 Score[SDB031]: -0.52
# R2 Score[SDB032]: -0.67
# R2 Score[SDB033]: -0.46
# R2 Score[SDB035]: -0.20
# R2 Score[SDB042]: -0.25
# R2 Score[SDB043]: -0.28
# R2 Score[SDB044]: -0.05
# R2 Score[SDB045]: -0.12
# R2 Score[SDB046]: -0.03
# R2 Score[SDB047]: -1.00
# R2 Score[SDB048]: -1.25
# R2 Score[SDB049]: 1.00
# R2 Score[SDB050]: -0.44
# R2 Score[SDB051]: -0.36
# R2 Score[SDB052]: -0.74
# R2 Score[SDB053]: -1.59
# R2 Score[SDB054]: -0.42
# R2 Score[SDB055]: 0.00
# R2 Score[SDB056]: -0.50
# R2 Score[SDB057]: -0.38
# R2 Score[SDB058]: -1.59
# R2 Score[SDB059]: -0.61
# R2 Score[SDB060]: -0.58
# R2 Score[SDB061]: -0.31
# R2 Score[SDB062]: -0.30
# R2 Score[SDB063]: -1.98
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# R2 Score[SDB065]: -0.25
# R2 Score[SDB142]: -3.39
# R2 Score[SDB143]: -0.07
# R2 Score[SDB144]: -0.41
# R2 Score[SDB64]: nan
# R2 Score[SMI001]: -0.22
# R2 Score[SMI002]: -0.07
# R2 Score[SMI003]: -0.06
# R2 Score[SMI004]: -0.17
# R2 Score[SMI005]: -0.20
# R2 Score[SMI006]: -0.21
# R2 Score[SMI007]: -0.97
# R2 Score[SMI008]: -0.49
# R2 Score[SMI009]: -0.18
# R2 Score[SMI010]: -0.29
# R2 Score[SMI011]: -0.40
# R2 Score[SMI012]: -0.16
# R2 Score[SMI013]: -0.63
# R2 Score[SMI014]: -0.30
# R2 Score[SMI015]: -0.63
# R2 Score[SMI016]: -0.06
# R2 Score[SMI017]: -0.25
# R2 Score[SMI018]: -0.22
# R2 Score[SMI019]: -0.08
# R2 Score[SMI020]: -0.19
# R2 Score[SMI021]: -0.12
# R2 Score[SMI022]: -0.10
# R2 Score[SMI023]: -0.05
# R2 Score[SMI024]: -0.35
# R2 Score[SMI025]: -0.21
# R2 Score[SMI026]: -0.98
# R2 Score[SMI027]: -0.13
# R2 Score[SMI028]: -0.34
# R2 Score[SMI029]: -0.66
# R2 Score[SMI030]: -0.65
# R2 Score[SMI031]: -0.27
# R2 Score[SMI032]: -0.76
# R2 Score[SMI033]: -0.17
# R2 Score[SMI034]: 0.00
# R2 Score[SMI035]: -1.54
# R2 Score[SMI036]: -0.26
# R2 Score[SMI037]: -0.24
# R2 Score[SMI038]: -0.76
# R2 Score[SMI039]: -0.46
# R2 Score[SMI040]: -0.27
# R2 Score[SMI041]: -0.09
# R2 Score[SMI042]: -0.28
# R2 Score[SMI043]: -0.34
# R2 Score[SMI044]: -0.13
# R2 Score[SMI046]: -0.64
# R2 Score[SMI047]: -1.01
# R2 Score[SMI048]: -0.65
# R2 Score[SMI049]: -0.36
# R2 Score[SMI050]: -0.12
# R2 Score[SMI051]: -0.55
# R2 Score[SMI053]: -0.56
# R2 Score[SMI057]: -0.53
# R2 Score[SMI060]: -0.23
# R2 Score[SMI062]: -0.28
# R2 Score[SMI063]: -0.21
# R2 Score[SMI065]: -0.12
# R2 Score[SMI066]: -0.19
# R2 Score[SMI067]: -0.15
# R2 Score[SMI068]: -2.60
# R2 Score[SMI070]: -0.67
# R2 Score[SMI071]: -0.35
# R2 Score[SMI072]: -0.04
# R2 Score[SMI073]: -0.87
# R2 Score[SMI075]: -0.17
# R2 Score[SMI076]: -0.62
# R2 Score[SMI077]: -1.76
# R2 Score[SMI078]: -0.54
# R2 Score[SMI079]: -0.48
# R2 Score[SMI080]: -0.85
# R2 Score[SMI081]: -0.69
# R2 Score[SMI082]: -0.10
# R2 Score[SMI083]: -0.09
# R2 Score[SMI084]: -0.41
# R2 Score[SMI086]: -0.13
# R2 Score[SMI088]: -0.35
# R2 Score[SMI093]: -0.40
# R2 Score[SMI099]: -0.33
# R2 Score[SMI100]: -0.30
# R2 Score[SMI102]: -0.13
# R2 Score[SMI103]: -3.08
# R2 Score[SMI107]: -0.08
# R2 Score[SMI108]: nan
# R2 Score[SMI113]: -0.16
# R2 Score[SMI114]: -0.17
# R2 Score[SMI115]: -0.26
# R2 Score[SMI116]: -0.17
# R2 Score[SMI118]: -3.81
# R2 Score[SMI119]: -0.49
# R2 Score[SMI120]: -0.24
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# R2 Score[SMI121]: -0.28
# R2 Score[SMI122]: -0.65
# R2 Score[SMI123]: -0.52
# R2 Score[SMI124]: -0.37
# R2 Score[SMI125]: -0.03
# R2 Score[SMI126]: -0.33
# R2 Score[SMI127]: -0.38
# R2 Score[SMI128]: -0.18
# R2 Score[SMI129]: -0.51
# R2 Score[SMI130]: -0.34
# R2 Score[SMI131]: -3.44
# R2 Score[SMI132]: -0.14
# R2 Score[SMI133]: -0.18
# R2 Score[SMI134]: -0.13
# R2 Score[SMI135]: -0.42
# R2 Score[SMI136]: -0.02
# R2 Score[SMI137]: -0.14
# R2 Score[SMI138]: -10.43
# R2 Score[SMI139]: -0.19
# R2 Score[SMI140]: -0.28
# R2 Score[SMI141]: -0.92
# R2 Score[SMI142]: -1.70
# R2 Score[SMI143]: -1.62
# R2 Score[SMI144]: 0.04
# R2 Score[SMI145]: -0.36
# R2 Score[SMI146]: -0.16
# R2 Score[SMI147]: -0.38
# R2 Score[SMI148]: -0.47
# R2 Score[SMI149]: -0.53
# R2 Score[SMI150]: -0.56
# R2 Score[SMI151]: -0.40
# R2 Score[SMI152]: -0.42
# R2 Score[SMI153]: -0.21
# R2 Score[SMI154]: -0.65
# R2 Score[SMI155]: -0.56
# R2 Score[SMI156]: -0.33
# R2 Score[SMI157]: -0.45
# R2 Score[SMI158]: 1.00
# R2 Score[SMI159]: -0.30
# R2 Score[SMI160]: -0.27
# R2 Score[SMI161]: -1.81
# R2 Score[SMI162]: -0.29
# R2 Score[SMI163]: -0.29
# R2 Score[SMI164]: -0.29
# R2 Score[SMI165]: -0.33
# R2 Score[SMI166]: -0.25
# R2 Score[SMI167]: -0.22
# R2 Score[SMI168]: -0.33
# R2 Score[SMI169]: -0.25
# R2 Score[SMI170]: -0.38
# R2 Score[SMI171]: -0.81
# R2 Score[SMI172]: -0.23
# R2 Score[SMI173]: -0.34
# R2 Score[SMI174]: -0.56
# R2 Score[SMI175]: -1.46
# R2 Score[SMI176]: -0.25
# R2 Score[SMI177]: -0.59
# R2 Score[SMI178]: -0.64
# R2 Score[SMI179]: -0.11
# R2 Score[SMI180]: -0.41
# R2 Score[SMI181]: -0.32
# R2 Score[SMI182]: 0.00
# R2 Score[SMI183]: nan
# R2 Score[SMI184]: -0.63
# R2 Score[SMI185]: -0.70
# R2 Score[SMI186]: -0.29
# R2 Score[SMI187]: -0.82
# R2 Score[SMI188]: -0.61
# R2 Score[SMI189]: -0.27
# R2 Score[SMI190]: -0.62
# R2 Score[SMI191]: -0.37
# R2 Score[SMI192]: 0.07
# R2 Score[SMI193]: -0.14
# R2 Score[SMI194]: -0.08
# R2 Score[SMI195]: -1.91
# R2 Score[SMI196]: -0.41
# R2 Score[SMI197]: 0.00
# R2 Score[SMI198]: -0.85
# R2 Score[SMI199]: -2.06
# R2 Score[SMI200]: -0.23
# R2 Score[SMI201]: -0.03
# R2 Score[SMI202]: -0.57
# R2 Score[SMI203]: -0.16
# R2 Score[SMI204]: 0.00
# R2 Score[SMI205]: -0.25
# R2 Score[SMI206]: -0.30
# R2 Score[SMI207]: -0.19
# R2 Score[SMI208]: -0.05
# R2 Score[SMI209]: -0.07
# R2 Score[SMI210]: 1.00
# R2 Score[SMI211]: -0.39
# R2 Score[SMI212]: -0.32
# R2 Score[SMI213]: -0.24
# R2 Score[SMI214]: -0.78
# R2 Score[SMI215]: -0.27
# R2 Score[SMI216]: 0.00
# R2 Score[SMI217]: nan
# R2 Score[Z001]: 1.00
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
#Averaging The R-Squared Score
totalValueR2 = 0

for i in dataBasedOnAllCustomerClean:
  totalValueR2 = totalValueR2 + r2[i]

avgValue = totalValueR2/len(dataBasedOnAllCustomerClean)
print("Average R-Squared Score:",avgValue)
# Out:
# Average R-Squared Score: nan

# %% [markdown]
# #Combining The Prediction Results With SALDCODE

# %%
#Combining The Prediction Results With SALDCODE
combined_df = {}

for i in dataBasedOnAllCustomerClean:
  combined_df[i] = pd.concat([dataBasedOnAllCustomerClean[i], saldCodeBasedOnAllCustomerClean[i]], axis=1, join='inner')

#Combining Dataframes Per Customer into One Dataframe
combined_df_2 = combined_df
all_values_concat = pd.concat(combined_df_2.values(), ignore_index=True)

# %%
#Drop The Unused Columns and Reorder The Dataframe Columns
final_pred_df = all_values_concat
final_pred_df.drop(columns = {'TOTAL', 'QTY', 'QTYRET','YEAR','MONTH','DAY'}, inplace=True)
final_pred_df_reordered = final_pred_df[['SALDCODE','PREDICTQTY','PREDICTRET']]

# %%
#Download The Dataframe That Contains The XGBoost Prediction Results
final_pred_df_reordered.to_csv('sald_predict.csv', index=False)
files.download('sald_predict.csv')
